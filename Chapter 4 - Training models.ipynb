# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
k=1000
X = 2*np.random.rand(k, 1)
y = 4 + 3*X+np.random.randn(k, 1)

# %%
plt.figure()
plt.plot(X, y, '.')
plt.ylim([0, 12])
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
X_b = np.c_[np.ones((k, 1)), X]  # add x0 = 1 to each instanceprint(X_b.shape)
theta = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best
# Out:
# array([[3.89873172],
#        [3.06905972]])

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
plt.figure()
plt.plot(X, y, '.')
plt.plot(X_new, y_predict)

# %%
# Goal is to compare the different learning options
n_epochs=250
eta = 0.1 # learning rate
m=100
n=1
X = 2*np.random.rand(m, n)
y = 4 + 3*X+np.random.randn(m, n)
X_b = np.c_[np.ones((m, n)), X]  # add x0 = 1 to each instanceprint(X_b.shape)

#theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
# Batch method

theta = np.random.rand(n+1, 1)
Theta = np.zeros((n+1, n_epochs))
for epoch in range(n_epochs):
    gradients = (2/m)*X_b.T.dot(X_b.dot(theta)-y)
    theta = theta - eta*gradients
    Theta[:, epoch] = np.squeeze(theta)
plt.figure()
plt.plot(Theta[0, :])
plt.plot(Theta[1, :])
# Mini batch
ThetaM = np.zeros((n+1, n_epochs))
batchSize = 10
theta = np.random.rand(n+1, 1)
mb=np.around(m/batchSize)
mb=value.astype(int)
print(value.astype(int), type(value.astype(int)))
for epoch in range(n_epochs):
    for instance in range(mb):
        xi = X_b[mb*instance:mb*instance+batchSize] # get a matrix out
        gradients = (2/mb)*xi.T.dot(xi.dot(theta)-y[mb*instance:mb*instance+batchSize]) # we need the matrix form to perform a matrix multiplication
        eta = learning_schedule(epoch * mb + instance)
        theta = theta - eta*gradients
        ThetaM[:, epoch] = np.squeeze(theta)
plt.figure()
plt.plot(ThetaM[0, :])
plt.plot(ThetaM[1, :]) 


# Stochastique method
t0 =5
t1=50
def learning_schedule(t):
    return t0 / (t + t1)
ThetaS = np.zeros((n+1, n_epochs))
theta = np.random.rand(n+1, 1)
print(X_b.shape)
for epoch in range(n_epochs):
    for instance in range(m):
        index = np.random.randint(m)
        xi = X_b[index:index+1] # get a matrix out
        gradients = 2*xi.T.dot(xi.dot(theta)-y[index:index+1]) # we need the matrix form to perform a matrix multiplication
        eta = learning_schedule(epoch * m + instance)
        theta = theta - eta*gradients
        ThetaS[:, epoch] = np.squeeze(theta)
plt.figure()
plt.plot(ThetaS[0, :])
plt.plot(ThetaS[1, :])
# Out:
# 10 <class 'numpy.int32'>
# (100, 2)

# %%
# Goal is to compare the different learning options
n_epochs=250
eta = 0.1 # learning rate
m=100
n=1
tol = 0.1
X = 2*np.random.rand(m, n)
y = 4 + 3*X+np.random.randn(m, n)
X_b = np.c_[np.ones((m, n)), X]  # add x0 = 1 to each instanceprint(X_b.shape)

#theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
# Batch method

theta = np.random.rand(n+1, 1)
Theta = np.zeros((n+1, n_epochs))
calcTol = 1
counter=0
while calcTol>tol and counter<1000:
    gradients = (2/m)*X_b.T.dot(X_b.dot(theta)-y)
    theta = theta - eta*gradients
    calcTol = (2/m)*sum((X_b.dot(theta)-y)**2)
    Theta[:, epoch] = np.squeeze(theta)
    counter = counter+1
plt.figure()
plt.plot(Theta[0, :])
plt.plot(Theta[1, :])
print("counter", counter, "calcTol", calcTol)
# Mini batch
ThetaM = np.zeros((n+1, n_epochs))
batchSize = 10
theta = np.random.rand(n+1, 1)
mb=np.around(m/batchSize)
mb=value.astype(int)
print(value.astype(int), type(value.astype(int)))
for epoch in range(n_epochs):
    for instance in range(mb):
        xi = X_b[mb*instance:mb*instance+batchSize] # get a matrix out
        gradients = (2/mb)*xi.T.dot(xi.dot(theta)-y[mb*instance:mb*instance+batchSize]) # we need the matrix form to perform a matrix multiplication
        eta = learning_schedule(epoch * mb + instance)
        theta = theta - eta*gradients
        ThetaM[:, epoch] = np.squeeze(theta)
plt.figure()
plt.plot(ThetaM[0, :])
plt.plot(ThetaM[1, :]) 


# Stochastique method
t0 =5
t1=50
def learning_schedule(t):
    return t0 / (t + t1)
ThetaS = np.zeros((n+1, n_epochs))
theta = np.random.rand(n+1, 1)
print(X_b.shape)
for epoch in range(n_epochs):
    for instance in range(m):
        index = np.random.randint(m)
        xi = X_b[index:index+1] # get a matrix out
        gradients = 2*xi.T.dot(xi.dot(theta)-y[index:index+1]) # we need the matrix form to perform a matrix multiplication
        eta = learning_schedule(epoch * m + instance)
        theta = theta - eta*gradients
        ThetaS[:, epoch] = np.squeeze(theta)
plt.figure()
plt.plot(ThetaS[0, :])
plt.plot(ThetaS[1, :])
# Out:
# counter 1000 calcTol [1.88520906]
# 10 <class 'numpy.int32'>
# (100, 2)
